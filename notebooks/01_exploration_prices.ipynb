# %% [markdown]
# Predicting Madrid Housing Prices Using Socioeconomic prices using Machiene Learning

# %% [markdown]
# 1. Import Libraries

# %%
# Import the Pandas library for data manipulation and analysis
import pandas as pd

# Import NumPy for numerical operations
import numpy as np

# Import Matplotlib for creating basic charts and graphs
import matplotlib.pyplot as plt

# Import Seaborn for creating attractive statistical visualisations
import seaborn as sns

# %% [markdown]
# 2. Load Datasets

# %%
# Loading Dataset 2: Average Declared Housing Price (euros/m2) by District and Neighborhood in Madrid
prices = pd.read_csv("../data/prices.csv", sep=";",skiprows=5)

# %%
# Display the first five rows
prices.head()
# Out:
#          Unnamed: 0        Unnamed: 1      2007    2007.1    2007.2  \
# 0               NaN               NaN  Euros/m2  Euros/m2  Euros/m2
# 1               NaN               NaN     Total    Nuevas    Usadas
# 2  Ciudad de Madrid  Ciudad de Madrid  3.746,27  3.479,98  3.859,89
# 3        01. Centro        01. Centro  4.798,92   4.988,4  4.768,62
# 4        01. Centro      011. Palacio        ..        ..        ..
#
#                         2007.3                       2007.4  \
# 0  Números índice (Madrid=100)  Números índice (Madrid=100)
# 1                        Total                       Nuevas
# 2                          100                          100
# 3                        128,1                       143,35
# 4                           ..                           ..
#
#                         2007.5                      2007.6  \
# 0  Números índice (Madrid=100)  Números índice (Total=100)
# 1                       Usadas                       Total
# 2                          100                         100
# 3                       123,54                         100
# 4                           ..                          ..
#
#                        2007.7  ...                      2024.8      2025  \
# 0  Números índice (Total=100)  ...  Números índice (Total=100)  Euros/m2
# 1                      Nuevas  ...                      Usadas     Total
# 2                       92,89  ...                      100,39  5.285,72
# 3                      103,95  ...                      100,18   7.147,7
# 4                          ..  ...                       99,32  6.895,15
#
#      2025.1    2025.2                       2025.3  \
# 0  Euros/m2  Euros/m2  Números índice (Madrid=100)
# 1    Nuevas    Usadas                        Total
# 2  5.041,46  5.333,59                          100
# 3  6.814,13  7.171,36                       135,23
# 4  6.421,28  6.954,58                       130,45
#
#                         2025.4                       2025.5  \
# 0  Números índice (Madrid=100)  Números índice (Madrid=100)
# 1                       Nuevas                       Usadas
# 2                          100                          100
# 3                       135,16                       134,46
# 4                       127,37                       130,39
#
#                        2025.6                      2025.7  \
# 0  Números índice (Total=100)  Números índice (Total=100)
# 1                       Total                      Nuevas
# 2                         100                       95,38
# 3                         100                       95,33
# 4                         100                       93,13
#
#                        2025.8
# 0  Números índice (Total=100)
# 1                      Usadas
# 2                      100,91
# 3                      100,33
# 4                      100,86
#
# [5 rows x 173 columns]

# %%
# Display the first ten rows
prices.head(10)
# Out:
#          Unnamed: 0        Unnamed: 1      2007    2007.1    2007.2  \
# 0               NaN               NaN  Euros/m2  Euros/m2  Euros/m2
# 1               NaN               NaN     Total    Nuevas    Usadas
# 2  Ciudad de Madrid  Ciudad de Madrid  3.746,27  3.479,98  3.859,89
# 3        01. Centro        01. Centro  4.798,92   4.988,4  4.768,62
# 4        01. Centro      011. Palacio        ..        ..        ..
# 5        01. Centro  012. Embajadores        ..        ..        ..
# 6        01. Centro       013. Cortes        ..        ..        ..
# 7        01. Centro     014. Justicia        ..        ..        ..
# 8        01. Centro  015. Universidad        ..        ..        ..
# 9        01. Centro          016. Sol        ..        ..        ..
#
#                         2007.3                       2007.4  \
# 0  Números índice (Madrid=100)  Números índice (Madrid=100)
# 1                        Total                       Nuevas
# 2                          100                          100
# 3                        128,1                       143,35
# 4                           ..                           ..
# 5                           ..                           ..
# 6                           ..                           ..
# 7                           ..                           ..
# 8                           ..                           ..
# 9                           ..                           ..
#
#                         2007.5                      2007.6  \
# 0  Números índice (Madrid=100)  Números índice (Total=100)
# 1                       Usadas                       Total
# 2                          100                         100
# 3                       123,54                         100
# 4                           ..                          ..
# 5                           ..                          ..
# 6                           ..                          ..
# 7                           ..                          ..
# 8                           ..                          ..
# 9                           ..                          ..
#
#                        2007.7  ...                      2024.8      2025  \
# 0  Números índice (Total=100)  ...  Números índice (Total=100)  Euros/m2
# 1                      Nuevas  ...                      Usadas     Total
# 2                       92,89  ...                      100,39  5.285,72
# 3                      103,95  ...                      100,18   7.147,7
# 4                          ..  ...                       99,32  6.895,15
# 5                          ..  ...                       99,95  6.054,75
# 6                          ..  ...                       99,71  7.246,75
# 7                          ..  ...                         100   9.541,9
# 8                          ..  ...                        99,6  7.135,43
# 9                          ..  ...                      101,95  7.696,61
#
#      2025.1    2025.2                       2025.3  \
# 0  Euros/m2  Euros/m2  Números índice (Madrid=100)
# 1    Nuevas    Usadas                        Total
# 2  5.041,46  5.333,59                          100
# 3  6.814,13  7.171,36                       135,23
# 4  6.421,28  6.954,58                       130,45
# 5  6.153,41  6.044,57                       114,55
# 6         0  7.246,75                        137,1
# 7  9.505,61  9.544,48                       180,52
# 8  6.682,45  7.149,96                       134,99
# 9         0  7.726,49                       145,61
#
#                         2025.4                       2025.5  \
# 0  Números índice (Madrid=100)  Números índice (Madrid=100)
# 1                       Nuevas                       Usadas
# 2                          100                          100
# 3                       135,16                       134,46
# 4                       127,37                       130,39
# 5                       122,06                       113,33
# 6                            0                       135,87
# 7                       188,55                       178,95
# 8                       132,55                       134,06
# 9                            0                       144,86
#
#                        2025.6                      2025.7  \
# 0  Números índice (Total=100)  Números índice (Total=100)
# 1                       Total                      Nuevas
# 2                         100                       95,38
# 3                         100                       95,33
# 4                         100                       93,13
# 5                         100                      101,63
# 6                         100                           0
# 7                         100                       99,62
# 8                         100                       93,65
# 9                         100                           0
#
#                        2025.8
# 0  Números índice (Total=100)
# 1                      Usadas
# 2                      100,91
# 3                      100,33
# 4                      100,86
# 5                       99,83
# 6                         100
# 7                      100,03
# 8                       100,2
# 9                      100,39
#
# [10 rows x 173 columns]

# %%
# Display the last five rows
prices.tail()
# Out:
#                                             Unnamed: 0       Unnamed: 1 2007  \
# 154                                        21. Barajas  215. Corralejos   ..
# 155                                                NaN              NaN  NaN
# 156                                                NaN              NaN  NaN
# 157         Fuente: Colegio de Registradores de España              NaN  NaN
# 158  Observaciones: Tasa de cobertura: La informaci...              NaN  NaN
#
#     2007.1 2007.2 2007.3 2007.4 2007.5 2007.6 2007.7  ...  2024.8     2025  \
# 154     ..     ..     ..     ..     ..     ..     ..  ...  102,26  4.890,3
# 155    NaN    NaN    NaN    NaN    NaN    NaN    NaN  ...     NaN      NaN
# 156    NaN    NaN    NaN    NaN    NaN    NaN    NaN  ...     NaN      NaN
# 157    NaN    NaN    NaN    NaN    NaN    NaN    NaN  ...     NaN      NaN
# 158    NaN    NaN    NaN    NaN    NaN    NaN    NaN  ...     NaN      NaN
#
#     2025.1    2025.2 2025.3 2025.4 2025.5 2025.6 2025.7  2025.8
# 154      0  4.902,36  92,52      0  91,91    100      0  100,25
# 155    NaN       NaN    NaN    NaN    NaN    NaN    NaN     NaN
# 156    NaN       NaN    NaN    NaN    NaN    NaN    NaN     NaN
# 157    NaN       NaN    NaN    NaN    NaN    NaN    NaN     NaN
# 158    NaN       NaN    NaN    NaN    NaN    NaN    NaN     NaN
#
# [5 rows x 173 columns]

# %%
# Display ten random rows
prices.sample(10)
# Out:
#          Unnamed: 0         Unnamed: 1      2007    2007.1   2007.2 2007.3  \
# 139   19. Vicálvaro  194. El Cañaveral         -         -        -      -
# 20       03. Retiro       032. Adelfas        ..        ..       ..     ..
# 153     21. Barajas         214. Timón        ..        ..       ..     ..
# 19       03. Retiro      031. Pacífico        ..        ..       ..     ..
# 107   14. Moratalaz     146. Vinateros        ..        ..       ..     ..
# 149     21. Barajas        21. Barajas  3.587,62  3.593,01  3.585,8  95,77
# 73       10. Latina        103. Lucero        ..        ..       ..     ..
# 128  17. Villaverde      173. Butarque        ..        ..       ..     ..
# 74       10. Latina        104. Aluche        ..        ..       ..     ..
# 47     07. Chamberí    071. Gaztambide        ..        ..       ..     ..
#
#      2007.4 2007.5 2007.6  2007.7  ...  2024.8      2025    2025.1    2025.2  \
# 139       -      -      -       -  ...  107,03  4.587,55  4.652,24  4.116,01
# 20       ..     ..     ..      ..  ...   98,87  5.741,86         0  5.741,25
# 153      ..     ..     ..      ..  ...  100,23  4.418,93         0  4.309,06
# 19       ..     ..     ..      ..  ...   99,58  6.286,22         0  6.287,24
# 107      ..     ..     ..      ..  ...  100,49  3.899,66         0  3.903,82
# 149  103,25   92,9    100  100,15  ...  100,72  4.611,65  5.557,96  4.413,92
# 73       ..     ..     ..      ..  ...   98,85  3.310,43  3.719,24  3.258,35
# 128      ..     ..     ..      ..  ...  101,33  3.143,01  2.580,54  3.236,76
# 74       ..     ..     ..      ..  ...  100,28   3.360,3  3.209,44  3.376,52
# 47       ..     ..     ..      ..  ...   96,34   7.413,6  7.431,02  7.412,01
#
#      2025.3  2025.4  2025.5 2025.6  2025.7  2025.8
# 139   86,79   92,28   77,17    100  101,41   89,72
# 20   108,63       0  107,64    100       0   99,99
# 153    83,6       0   80,79    100       0   97,51
# 19   118,93       0  117,88    100       0  100,02
# 107   73,78       0   73,19    100       0  100,11
# 149   87,25  110,25   82,76    100  120,52   95,71
# 73    62,63   73,77   61,09    100  112,35   98,43
# 128   59,46   51,19   60,69    100    82,1  102,98
# 74    63,57   63,66   63,31    100   95,51  100,48
# 47   140,26   147,4  138,97    100  100,23   99,98
#
# [10 rows x 173 columns]

# %%
# Check the number of rows and columns
prices.shape
# Out:
# (159, 173)

# %%
# Display all column names
prices.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', '2007', '2007.1', '2007.2', '2007.3',
#        '2007.4', '2007.5', '2007.6', '2007.7',
#        ...
#        '2024.8', '2025', '2025.1', '2025.2', '2025.3', '2025.4', '2025.5',
#        '2025.6', '2025.7', '2025.8'],
#       dtype='object', length=173)

# %%
# Display the data type of each column
prices.dtypes
# Out:
# Unnamed: 0    object
# Unnamed: 1    object
# 2007          object
# 2007.1        object
# 2007.2        object
#                ...
# 2025.4        object
# 2025.5        object
# 2025.6        object
# 2025.7        object
# 2025.8        object
# Length: 173, dtype: object

# %%
# Display dataset information
prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Columns: 173 entries, Unnamed: 0 to 2025.8
# dtypes: object(173)
# memory usage: 215.0+ KB

# %%
# Summary statistics
prices.describe()
# Out:
#                Unnamed: 0        Unnamed: 1 2007 2007.1 2007.2 2007.3 2007.4  \
# count                 155               153  155    155    155    155    155
# unique                 24               153   26     26     26     26     26
# top     15. Ciudad Lineal  Ciudad de Madrid   ..     ..     ..     ..     ..
# freq                   10                 1  128    128    128    128    128
#
#        2007.5 2007.6 2007.7  ... 2024.8      2025 2025.1 2025.2  \
# count     155    155    155  ...    155       155    155    155
# unique     26      5     26  ...    133       155     94    154
# top        ..     ..     ..  ...    100  Euros/m2      0      0
# freq      128    128    128  ...     10         1     62      2
#
#                              2025.3 2025.4 2025.5 2025.6 2025.7 2025.8
# count                           155    155    155    155    155    155
# unique                          155     94    154      3     94    125
# top     Números índice (Madrid=100)      0      0    100      0    100
# freq                              1     62      2    153     62      8
#
# [4 rows x 173 columns]

# %%
# Summary statistics for all columns
prices.describe(include="all")
# Out:
#                Unnamed: 0        Unnamed: 1 2007 2007.1 2007.2 2007.3 2007.4  \
# count                 155               153  155    155    155    155    155
# unique                 24               153   26     26     26     26     26
# top     15. Ciudad Lineal  Ciudad de Madrid   ..     ..     ..     ..     ..
# freq                   10                 1  128    128    128    128    128
#
#        2007.5 2007.6 2007.7  ... 2024.8      2025 2025.1 2025.2  \
# count     155    155    155  ...    155       155    155    155
# unique     26      5     26  ...    133       155     94    154
# top        ..     ..     ..  ...    100  Euros/m2      0      0
# freq      128    128    128  ...     10         1     62      2
#
#                              2025.3 2025.4 2025.5 2025.6 2025.7 2025.8
# count                           155    155    155    155    155    155
# unique                          155     94    154      3     94    125
# top     Números índice (Madrid=100)      0      0    100      0    100
# freq                              1     62      2    153     62      8
#
# [4 rows x 173 columns]

# %%
# Count missing values
prices.isnull().sum()
# Out:
# Unnamed: 0    4
# Unnamed: 1    6
# 2007          4
# 2007.1        4
# 2007.2        4
#              ..
# 2025.4        4
# 2025.5        4
# 2025.6        4
# 2025.7        4
# 2025.8        4
# Length: 173, dtype: int64

# %%
# Count duplicate rows
prices.duplicated().sum()
# Out:
# np.int64(1)

# %%
# Count unique values
# A method that counts the number of unique (distinct) values in each column.
prices.nunique()
# Out:
# Unnamed: 0     24
# Unnamed: 1    153
# 2007           26
# 2007.1         26
# 2007.2         26
#              ...
# 2025.4         94
# 2025.5        154
# 2025.6          3
# 2025.7         94
# 2025.8        125
# Length: 173, dtype: int64

# %% [markdown]
# # Predicting Average House Prices in Madrid Neighbourhoods Using Socioeconomic Indicators

# %% [markdown]
# ## 1. Data Inspection

# %% [markdown]
# ### Introduction
# Two datasets are used in this project:
#
# - Madrid neighbourhood socioeconomic indicator data (indicators.csv)
# - Madrid neighbourhood housing price data (prices.csv)
#
# This notebook focuses on exploring the raw Madrid neighbourhood housing price dataset. The dataset contains average housing prices for new, used and total housing across multiple years, with data available at both district and neighbourhood level.

# %% [markdown]
# ### Import Libraries

# %%
# Import the Pandas library for data manipulation and analysis
import pandas as pd

# %% [markdown]
# ### Load Dataset

# %%
# Loading Dataset 2: Average Declared Housing Price (euros/m2) by District and Neighborhood in Madrid
prices = pd.read_csv("../data/prices.csv", sep=";",skiprows=5)

# %% [markdown]
# ### Observations
#
# After the dataset initially failed to load correctly, inspection of prices.csv showed that the first five rows contained metadata. These rows were therefore skipped when loading the dataset.

# %% [markdown]
# ### Initial Inspection

# %%
# Display the first ten rows
prices.head(10)
# Out:
#          Unnamed: 0        Unnamed: 1      2007    2007.1    2007.2  \
# 0               NaN               NaN  Euros/m2  Euros/m2  Euros/m2
# 1               NaN               NaN     Total    Nuevas    Usadas
# 2  Ciudad de Madrid  Ciudad de Madrid  3.746,27  3.479,98  3.859,89
# 3        01. Centro        01. Centro  4.798,92   4.988,4  4.768,62
# 4        01. Centro      011. Palacio        ..        ..        ..
# 5        01. Centro  012. Embajadores        ..        ..        ..
# 6        01. Centro       013. Cortes        ..        ..        ..
# 7        01. Centro     014. Justicia        ..        ..        ..
# 8        01. Centro  015. Universidad        ..        ..        ..
# 9        01. Centro          016. Sol        ..        ..        ..
#
#                         2007.3                       2007.4  \
# 0  Números índice (Madrid=100)  Números índice (Madrid=100)
# 1                        Total                       Nuevas
# 2                          100                          100
# 3                        128,1                       143,35
# 4                           ..                           ..
# 5                           ..                           ..
# 6                           ..                           ..
# 7                           ..                           ..
# 8                           ..                           ..
# 9                           ..                           ..
#
#                         2007.5                      2007.6  \
# 0  Números índice (Madrid=100)  Números índice (Total=100)
# 1                       Usadas                       Total
# 2                          100                         100
# 3                       123,54                         100
# 4                           ..                          ..
# 5                           ..                          ..
# 6                           ..                          ..
# 7                           ..                          ..
# 8                           ..                          ..
# 9                           ..                          ..
#
#                        2007.7  ...                      2024.8      2025  \
# 0  Números índice (Total=100)  ...  Números índice (Total=100)  Euros/m2
# 1                      Nuevas  ...                      Usadas     Total
# 2                       92,89  ...                      100,39  5.285,72
# 3                      103,95  ...                      100,18   7.147,7
# 4                          ..  ...                       99,32  6.895,15
# 5                          ..  ...                       99,95  6.054,75
# 6                          ..  ...                       99,71  7.246,75
# 7                          ..  ...                         100   9.541,9
# 8                          ..  ...                        99,6  7.135,43
# 9                          ..  ...                      101,95  7.696,61
#
#      2025.1    2025.2                       2025.3  \
# 0  Euros/m2  Euros/m2  Números índice (Madrid=100)
# 1    Nuevas    Usadas                        Total
# 2  5.041,46  5.333,59                          100
# 3  6.814,13  7.171,36                       135,23
# 4  6.421,28  6.954,58                       130,45
# 5  6.153,41  6.044,57                       114,55
# 6         0  7.246,75                        137,1
# 7  9.505,61  9.544,48                       180,52
# 8  6.682,45  7.149,96                       134,99
# 9         0  7.726,49                       145,61
#
#                         2025.4                       2025.5  \
# 0  Números índice (Madrid=100)  Números índice (Madrid=100)
# 1                       Nuevas                       Usadas
# 2                          100                          100
# 3                       135,16                       134,46
# 4                       127,37                       130,39
# 5                       122,06                       113,33
# 6                            0                       135,87
# 7                       188,55                       178,95
# 8                       132,55                       134,06
# 9                            0                       144,86
#
#                        2025.6                      2025.7  \
# 0  Números índice (Total=100)  Números índice (Total=100)
# 1                       Total                      Nuevas
# 2                         100                       95,38
# 3                         100                       95,33
# 4                         100                       93,13
# 5                         100                      101,63
# 6                         100                           0
# 7                         100                       99,62
# 8                         100                       93,65
# 9                         100                           0
#
#                        2025.8
# 0  Números índice (Total=100)
# 1                      Usadas
# 2                      100,91
# 3                      100,33
# 4                      100,86
# 5                       99,83
# 6                         100
# 7                      100,03
# 8                       100,2
# 9                      100,39
#
# [10 rows x 173 columns]

# %%
# Display the last five rows
prices.tail()
# Out:
#                                             Unnamed: 0       Unnamed: 1 2007  \
# 154                                        21. Barajas  215. Corralejos   ..
# 155                                                NaN              NaN  NaN
# 156                                                NaN              NaN  NaN
# 157         Fuente: Colegio de Registradores de España              NaN  NaN
# 158  Observaciones: Tasa de cobertura: La informaci...              NaN  NaN
#
#     2007.1 2007.2 2007.3 2007.4 2007.5 2007.6 2007.7  ...  2024.8     2025  \
# 154     ..     ..     ..     ..     ..     ..     ..  ...  102,26  4.890,3
# 155    NaN    NaN    NaN    NaN    NaN    NaN    NaN  ...     NaN      NaN
# 156    NaN    NaN    NaN    NaN    NaN    NaN    NaN  ...     NaN      NaN
# 157    NaN    NaN    NaN    NaN    NaN    NaN    NaN  ...     NaN      NaN
# 158    NaN    NaN    NaN    NaN    NaN    NaN    NaN  ...     NaN      NaN
#
#     2025.1    2025.2 2025.3 2025.4 2025.5 2025.6 2025.7  2025.8
# 154      0  4.902,36  92,52      0  91,91    100      0  100,25
# 155    NaN       NaN    NaN    NaN    NaN    NaN    NaN     NaN
# 156    NaN       NaN    NaN    NaN    NaN    NaN    NaN     NaN
# 157    NaN       NaN    NaN    NaN    NaN    NaN    NaN     NaN
# 158    NaN       NaN    NaN    NaN    NaN    NaN    NaN     NaN
#
# [5 rows x 173 columns]

# %%
# Display ten random rows
prices.sample(10)
# Out:
#                 Unnamed: 0             Unnamed: 1      2007    2007.1  \
# 80         11. Carabanchel            112. Opañel        ..        ..
# 133  18. Villa de Vallecas     182. Santa Eugenia        ..        ..
# 77              10. Latina           107. Águilas        ..        ..
# 15          02. Arganzuela          025. Delicias        ..        ..
# 128         17. Villaverde          173. Butarque        ..        ..
# 17          02. Arganzuela            027. Atocha        ..        ..
# 123          16. Hortaleza  165. Apóstol Santiago        ..        ..
# 11          02. Arganzuela          021. Imperial        ..        ..
# 151            21. Barajas        212. Aeropuerto        ..        ..
# 125         17. Villaverde         17. Villaverde  2.785,93  2.983,66
#
#        2007.2 2007.3 2007.4 2007.5 2007.6 2007.7  ...  2024.8      2025  \
# 80         ..     ..     ..     ..     ..     ..  ...   95,59  3.500,89
# 133        ..     ..     ..     ..     ..     ..  ...   99,77  2.899,99
# 77         ..     ..     ..     ..     ..     ..  ...    98,5  3.231,64
# 15         ..     ..     ..     ..     ..     ..  ...  100,14  5.426,01
# 128        ..     ..     ..     ..     ..     ..  ...  101,33  3.143,01
# 17         ..     ..     ..     ..     ..     ..  ...       0  6.810,36
# 123        ..     ..     ..     ..     ..     ..  ...   99,05  4.162,46
# 11         ..     ..     ..     ..     ..     ..  ...   83,54  5.855,12
# 151        ..     ..     ..     ..     ..     ..  ...       0         0
# 125  2.645,56  74,37  85,74  68,54    100  107,1  ...   99,94   2.649,6
#
#        2025.1    2025.2  2025.3  2025.4  2025.5 2025.6  2025.7  2025.8
# 80    3.794,8  3.469,85   66,23   75,27   65,06    100   108,4   99,11
# 133         0  2.896,34   54,86       0    54,3    100       0   99,87
# 77   3.334,33  3.216,08   61,14   66,14    60,3    100  103,18   99,52
# 15          0  5.499,92  102,65       0  103,12    100       0  101,36
# 128  2.580,54  3.236,76   59,46   51,19   60,69    100    82,1  102,98
# 17   6.828,78         0  128,84  135,45       0    100    2,56       0
# 123  4.605,35  4.096,02   78,75   91,35    76,8    100  110,64    98,4
# 11   6.010,51  5.776,45  110,77  119,22   108,3    100  102,65   98,66
# 151         0         0       0       0       0    100       0       0
# 125  2.515,56  2.675,35   50,13    49,9   50,16    100   94,94  100,97
#
# [10 rows x 173 columns]

# %%
# Check the number of rows and columns
prices.shape
# Out:
# (159, 173)

# %%
# Display all column names
prices.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', '2007', '2007.1', '2007.2', '2007.3',
#        '2007.4', '2007.5', '2007.6', '2007.7',
#        ...
#        '2024.8', '2025', '2025.1', '2025.2', '2025.3', '2025.4', '2025.5',
#        '2025.6', '2025.7', '2025.8'],
#       dtype='str', length=173)

# %% [markdown]
# ### Observations
#
# The dataset contains multi-year data at both district and neighbourhood level. Each row represents either the city of Madrid, a district or a neighbourhood, while the columns contain the corresponding average housing price in euros per square metre for new, used and total housing between 2007 and 2025.
#
# While some metadata was removed when loading the dataset, the column titles remain split across the header and first two rows. Additionally, the final four rows (1555–1558) appear to contain metadata rather than housing price observations. The data therefore requires further removal of metadata, restructuring and filtering by year, housing type and geographical level to obtain the target variable for eventual modelling.

# %% [markdown]
# ### Data Types

# %%
# Display the data type of each column
prices.dtypes
# Out:
# Unnamed: 0    str
# Unnamed: 1    str
# 2007          str
# 2007.1        str
# 2007.2        str
#              ...
# 2025.4        str
# 2025.5        str
# 2025.6        str
# 2025.7        str
# 2025.8        str
# Length: 173, dtype: object

# %%
# Display dataset information
prices.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Columns: 173 entries, Unnamed: 0 to 2025.8
# dtypes: str(173)
# memory usage: 327.0 KB

# %% [markdown]
# ### Observations
# The dataset contains 173 columns, which are initially stored as the object data type. As this project focuses specifically on 2025 data, the relevant housing price values will need to be converted to a numerical data type (float) before modelling.
#
# Additionally, the values use European number formatting, with a comma (,) as the decimal separator and a period (.) as the thousands separator. These values will therefore need to be reformatted to ensure they are interpreted correctly as numerical data.

# %%
# Summary statistics
prices.describe()
# Out:
#                Unnamed: 0        Unnamed: 1 2007 2007.1 2007.2 2007.3 2007.4  \
# count                 155               153  155    155    155    155    155
# unique                 24               153   26     26     26     26     26
# top     15. Ciudad Lineal  Ciudad de Madrid   ..     ..     ..     ..     ..
# freq                   10                 1  128    128    128    128    128
#
#        2007.5 2007.6 2007.7  ... 2024.8      2025 2025.1 2025.2  \
# count     155    155    155  ...    155       155    155    155
# unique     26      5     26  ...    133       155     94    154
# top        ..     ..     ..  ...    100  Euros/m2      0      0
# freq      128    128    128  ...     10         1     62      2
#
#                              2025.3 2025.4 2025.5 2025.6 2025.7 2025.8
# count                           155    155    155    155    155    155
# unique                          155     94    154      3     94    125
# top     Números índice (Madrid=100)      0      0    100      0    100
# freq                              1     62      2    153     62      8
#
# [4 rows x 173 columns]

# %%
# Summary statistics for all columns
prices.describe(include="all")
# Out:
#                Unnamed: 0        Unnamed: 1 2007 2007.1 2007.2 2007.3 2007.4  \
# count                 155               153  155    155    155    155    155
# unique                 24               153   26     26     26     26     26
# top     15. Ciudad Lineal  Ciudad de Madrid   ..     ..     ..     ..     ..
# freq                   10                 1  128    128    128    128    128
#
#        2007.5 2007.6 2007.7  ... 2024.8      2025 2025.1 2025.2  \
# count     155    155    155  ...    155       155    155    155
# unique     26      5     26  ...    133       155     94    154
# top        ..     ..     ..  ...    100  Euros/m2      0      0
# freq      128    128    128  ...     10         1     62      2
#
#                              2025.3 2025.4 2025.5 2025.6 2025.7 2025.8
# count                           155    155    155    155    155    155
# unique                          155     94    154      3     94    125
# top     Números índice (Madrid=100)      0      0    100      0    100
# freq                              1     62      2    153     62      8
#
# [4 rows x 173 columns]

# %% [markdown]
# ### Missing Values and Duplicates

# %%
# Count missing values
prices.isnull().sum()
# Out:
# Unnamed: 0    4
# Unnamed: 1    6
# 2007          4
# 2007.1        4
# 2007.2        4
#              ..
# 2025.4        4
# 2025.5        4
# 2025.6        4
# 2025.7        4
# 2025.8        4
# Length: 173, dtype: int64

# %%
# Count duplicate rows
prices.duplicated().sum()
# Out:
# np.int64(1)

# %%
# Count number of unique values in each column
prices.nunique()
# Out:
# Unnamed: 0     24
# Unnamed: 1    153
# 2007           26
# 2007.1         26
# 2007.2         26
#              ...
# 2025.4         94
# 2025.5        154
# 2025.6          3
# 2025.7         94
# 2025.8        125
# Length: 173, dtype: int64

# %% [markdown]
# ### Observations
#
# Initial summary statistics are of limited value at this stage, as the data has not yet been cleaned. Missing values indicate that not every observation contains a value for each corresponding column. Inspection using tail() also shows that the final four rows contain information outside of the main dataset, which may account for some of the identified missing values.
#
# One duplicate row was also identified during the initial inspection. This may be associated with the metadata contained within the final rows and will be investigated during data cleaning.

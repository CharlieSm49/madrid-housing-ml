# %% [markdown]
# # Predicting Average House Prices in Madrid Neighbourhoods Using Socioeconomic Indicators

# %% [markdown]
# ## Overall Project Aim:
# To develop and evaluate a machine learning model that uses 2025 socioeconomic indicators to predict average housing prices across Madrid neighbourhoods.

# %% [markdown]
# ## 2. Feature Selection

# %% [markdown]
# ### Introduction
# Following the initial exploration of the raw data, the socioeconomic indicators included in the dataset will need to be examined to identify appropriate features for the machine learning model. The purpose of this notebook is to explore these indicators and select relevant features for subsequent analysis and modelling.

# %% [markdown]
# ### Import Libraries

# %%
# Import the Pandas library for data manipulation and analysis
import pandas as pd

# %% [markdown]
# ### Load Dataset

# %%
# Loading Dataset 1: Panel of Sociodemographic Indicators of Districts and Neighborhoods of Madrid
indicators = pd.read_csv("../data/indicators.csv",sep=";")

# %%
# Create a clean working copy of dataset
indicators_clean = indicators.copy()

# %% [markdown]
# ### Initial Inspection and Column Rename

# %%
# Display the first five rows
indicators_clean.head()
# Out:
#    Orden  Periodo panel            ciudad  cod_distrito distrito  cod_barrio  \
# 0      1           2020  Ciudad de Madrid           1.0   Centro         NaN
# 1      2           2020  Ciudad de Madrid           1.0   Centro         NaN
# 2      3           2020  Ciudad de Madrid           1.0   Centro         NaN
# 3      4           2020  Ciudad de Madrid           1.0   Centro         NaN
# 4      5           2020  Ciudad de Madrid           1.0   Centro         NaN
#
#   barrio   año fecha_indicador                    fuente_indicador  \
# 0    NaN  2019      01/01/2019  Estadística Ayuntamiento de Madrid
# 1    NaN  2019      01/01/2019  Estadística Ayuntamiento de Madrid
# 2    NaN  2019      01/01/2019  Estadística Ayuntamiento de Madrid
# 3    NaN  2019      01/01/2019  Estadística Ayuntamiento de Madrid
# 4    NaN  2019      01/01/2019  Estadística Ayuntamiento de Madrid
#
#                                      categoría_1              categoría_2  \
# 0  Características Generales del Distrito-Barrio                      NaN
# 1  Características Generales del Distrito-Barrio                      NaN
# 2                         Población del distrito  Estructura de población
# 3                         Población del distrito  Estructura de población
# 4                         Población del distrito  Estructura de población
#
#         indicador_nivel1 indicador_nivel2 indicador_nivel3 unidad_indicador  \
# 0             Superficie              NaN              NaN               Ha
# 1  Densidad de población              NaN              NaN   Habitantes/Ha.
# 2   Número de Habitantes              NaN              NaN       Habitantes
# 3   Número de Habitantes          Hombres              NaN       Habitantes
# 4   Número de Habitantes          Mujeres              NaN       Habitantes
#
#               indicador_completo valor_indicador
# 0               Superficie (ha.)             523
# 1  Población densidad (hab./ha.)             258
# 2              Número habitantes          134881
# 3              Población hombres           67829
# 4              Población mujeres           67052

# %%
# Rename columns

indicators_clean.rename(columns={
    "Orden": "row_no",
    "Periodo panel": "dataset_version",
    "ciudad": "city",
    "cod_distrito": "district_code",
    "distrito": "district_name",
    "cod_barrio": "neighbourhood_code",
    "barrio": "neighbourhood_name",
    "año": "year",
    "fecha_indicador": "date",
    "fuente_indicador": "data_source",
    "categoría_1": "main_category",
    "categoría_2": "subcategory",
    "indicador_nivel1": "indicator_level1",
    "indicador_nivel2": "indicator_level2",
    "indicador_nivel3": "indicator_level3",
    "unidad_indicador": "unit",
    "indicador_completo": "indicator_name",
    "valor_indicador": "indicator_value"
}, inplace=True)

# %%
# Display the first ten rows following column rename
indicators_clean.head(10)
# Out:
#    row_no  dataset_version              city  district_code district_name  \
# 0       1             2020  Ciudad de Madrid            1.0        Centro
# 1       2             2020  Ciudad de Madrid            1.0        Centro
# 2       3             2020  Ciudad de Madrid            1.0        Centro
# 3       4             2020  Ciudad de Madrid            1.0        Centro
# 4       5             2020  Ciudad de Madrid            1.0        Centro
# 5       6             2020  Ciudad de Madrid            1.0        Centro
# 6       7             2020  Ciudad de Madrid            1.0        Centro
# 7       8             2020  Ciudad de Madrid            1.0        Centro
# 8       9             2020  Ciudad de Madrid            1.0        Centro
# 9      10             2020  Ciudad de Madrid            1.0        Centro
#
#    neighbourhood_code neighbourhood_name  year        date  \
# 0                 NaN                NaN  2019  01/01/2019
# 1                 NaN                NaN  2019  01/01/2019
# 2                 NaN                NaN  2019  01/01/2019
# 3                 NaN                NaN  2019  01/01/2019
# 4                 NaN                NaN  2019  01/01/2019
# 5                 NaN                NaN  2019  01/01/2019
# 6                 NaN                NaN  2019  01/01/2019
# 7                 NaN                NaN  2019  01/01/2019
# 8                 NaN                NaN  2019  01/01/2019
# 9                 NaN                NaN  2019  01/01/2019
#
#                           data_source  \
# 0  Estadística Ayuntamiento de Madrid
# 1  Estadística Ayuntamiento de Madrid
# 2  Estadística Ayuntamiento de Madrid
# 3  Estadística Ayuntamiento de Madrid
# 4  Estadística Ayuntamiento de Madrid
# 5  Estadística Ayuntamiento de Madrid
# 6  Estadística Ayuntamiento de Madrid
# 7  Estadística Ayuntamiento de Madrid
# 8  Estadística Ayuntamiento de Madrid
# 9  Estadística Ayuntamiento de Madrid
#
#                                    main_category              subcategory  \
# 0  Características Generales del Distrito-Barrio                      NaN
# 1  Características Generales del Distrito-Barrio                      NaN
# 2                         Población del distrito  Estructura de población
# 3                         Población del distrito  Estructura de población
# 4                         Población del distrito  Estructura de población
# 5                         Población del distrito  Estructura de población
# 6                         Población del distrito  Estructura de población
# 7                         Población del distrito  Estructura de población
# 8                         Población del distrito  Estructura de población
# 9                         Población del distrito  Estructura de población
#
#         indicator_level1 indicator_level2 indicator_level3            unit  \
# 0             Superficie              NaN              NaN              Ha
# 1  Densidad de población              NaN              NaN  Habitantes/Ha.
# 2   Número de Habitantes              NaN              NaN      Habitantes
# 3   Número de Habitantes          Hombres              NaN      Habitantes
# 4   Número de Habitantes          Mujeres              NaN      Habitantes
# 5             Edad Media              NaN              NaN            Edad
# 6   Número de Habitantes             0-14              NaN        Personas
# 7   Número de Habitantes            15-29              NaN        Personas
# 8   Número de Habitantes            30-44              NaN        Personas
# 9   Número de Habitantes            45-64              NaN        Personas
#
#                   indicator_name indicator_value
# 0               Superficie (ha.)             523
# 1  Población densidad (hab./ha.)             258
# 2              Número habitantes          134881
# 3              Población hombres           67829
# 4              Población mujeres           67052
# 5     Edad media de la población           44,03
# 6       Población de 0 a 14 años           10554
# 7      Población de 15 a 29 años           21800
# 8      Población de 30 a 44 años           42857
# 9      Población de 45 a 64 años           38025

# %%
# Checking dataset coverage across different years
indicators_clean["dataset_version"].value_counts().sort_index()
# Out:
# dataset_version
# 2020    18846
# 2021    19493
# 2022    18906
# 2023    19578
# 2024    19569
# 2025    20516
# Name: count, dtype: int64

# %% [markdown]
# ### Observations
# As the model aims to use the most recent available data, 2025 was selected as the year of analysis. A check was conducted to confirm that 2025 had comparable data coverage to other recorded years, helping to validate its suitability for use in the model.

# %% [markdown]
# ### Inspecting Neighbhourhood Names

# %%
#Display unique dataset names
indicators_clean["neighbourhood_name"].nunique()
# Out:
# 131

# %%
# Remove rows where neighbourhood_name is missing
indicators_clean_n= indicators_clean.dropna(subset=["neighbourhood_name"])

# %%
indicators_clean_n.sample(10)
# Out:
#         row_no  dataset_version              city  district_code  \
# 111038  111039             2025  Ciudad de Madrid           16.0
# 82978    82979             2024  Ciudad de Madrid            8.0
# 106063  106064             2025  Ciudad de Madrid           11.0
# 97589    97590             2025  Ciudad de Madrid            2.0
# 13337    13338             2020  Ciudad de Madrid           16.0
# 90214    90215             2024  Ciudad de Madrid           17.0
# 98805    98806             2025  Ciudad de Madrid            3.0
# 100573  100574             2025  Ciudad de Madrid            5.0
# 101981  101982             2025  Ciudad de Madrid            7.0
# 76266    76267             2023  Ciudad de Madrid            6.0
#
#               district_name  neighbourhood_code neighbourhood_name  year  \
# 111038            Hortaleza               163.0           Canillas  2023
# 82978   Fuencarral-El Pardo                84.0              Pilar  2023
# 106063          Carabanchel               113.0         San Isidro  2025
# 97589            Arganzuela                22.0            Acacias  2025
# 13337             Hortaleza               165.0   Apóstol Santiago  2019
# 90214            Villaverde               174.0        Los Rosales  2024
# 98805                Retiro                35.0      Los Jerónimos  2025
# 100573            Chamartín                55.0       Nueva España  2023
# 101981             Chamberí                71.0         Gaztambide  2023
# 76266                Tetuán                65.0      Valdeacederas  2023
#
#               date                                        data_source  \
# 111038  28/05/2023                 Estadística Ayuntamiento de Madrid
# 82978   01/01/2023                 Estadística Ayuntamiento de Madrid
# 106063  01/01/2025                 Estadística Ayuntamiento de Madrid
# 97589   01/01/2025  Portal de datos abiertos del Ayuntamiento de M...
# 13337   01/01/2019                 Estadística Ayuntamiento de Madrid
# 90214   01/01/2024                 Estadística Ayuntamiento de Madrid
# 98805   01/01/2025                 Estadística Ayuntamiento de Madrid
# 100573  01/01/2023  Portal web del Ayuntamiento de Madrid (https:/...
# 101981  28/05/2023                 Estadística Ayuntamiento de Madrid
# 76266   01/01/2023  Portal de datos abiertos del Ayuntamiento de M...
#
#                                 main_category                     subcategory  \
# 111038          Resultados Elecciones Locales                             NaN
# 82978                  Población del distrito         Estructura de población
# 106063        Indicadores Población desempleo             Población desempleo
# 97589   Servicios y equipamientos Municipales  Servicios Sociales Municipales
# 13337                  Población del distrito         Estructura de población
# 90214                  Población del distrito         Estructura de población
# 98805         Indicadores Población desempleo             Población desempleo
# 100573               Índice de vulnerabilidad                     Territorial
# 101981          Resultados Elecciones Locales                             NaN
# 76266                      Empresa y comercio                Locales abiertos
#
#                   indicator_level1  \
# 111038             Número de votos
# 82978         Número de Habitantes
# 106063  Número de personas paradas
# 97589      Número de equipamientos
# 13337         Número de Habitantes
# 90214         Número de Habitantes
# 98805   Número de personas paradas
# 100573        Resultado del índice
# 101981             Número de votos
# 76266                      Locales
#
#                                          indicator_level2  \
# 111038                                      Podemos-IU-AV
# 82978                               Nacionalidad española
# 106063                                            Hombres
# 97589               Centros de Apoyo a las Familias (CAF)
# 13337   Extranjeros menos UE y resto países de OCDE / ...
# 90214                                                0-14
# 98805                                             Hombres
# 100573                                     Vulnerabilidad
# 101981                                               PSOE
# 76266                                            Abiertos
#
#            indicator_level3           unit  \
# 111038            Municipio          Votos
# 82978                   NaN       Personas
# 106063                  NaN           Tasa
# 97589                   NaN  Equipamientos
# 13337    Personas migrantes     Proporción
# 90214                   NaN       Personas
# 98805       De 45 a 64 años           Tasa
# 100573  Educación y Cultura         Índice
# 101981            Municipio          Votos
# 76266                   NaN         Número
#
#                                            indicator_name indicator_value
# 111038  Elecciones municipales, votos a Podemos-Izquie...            1005
# 82978                  Personas con nacionalidad española           39433
# 106063           Tasa absoluta de paro registrado hombres            5,33
# 97589               Centros de apoyo a las familias (CAF)               0
# 13337   Proporción de personas migrantes (personas ext...          0,0611
# 90214                            Población de 0 a 14 años            4790
# 98805        Tasa de desempleo en hombres de 45 a 64 años            1,95
# 100573       Índice de vulnerabilidad educación y cultura     5,888205883
# 101981  Elecciones municipales, votos al Partido Socia...            1597
# 76266            Número de locales dados de alta abiertos             775

# %%
# Obtaining a sample of neighbourhood names to compare for obtaining a foreign key to later merging

indicators_clean_n[
    ["neighbourhood_code", "neighbourhood_name"]
].drop_duplicates().head(20)
# Out:
#       neighbourhood_code    neighbourhood_name
# 186                 11.0               Palacio
# 269                 12.0           Embajadores
# 351                 13.0                Cortes
# 425                 14.0              Justicia
# 508                 15.0           Universidad
# 591                 16.0                   Sol
# 995                 21.0              Imperial
# 1070                22.0               Acacias
# 1148                23.0               Chopera
# 1227                24.0               Legazpi
# 1301                25.0              Delicias
# 1376                26.0  Palos de la Frontera
# 1456                27.0                Atocha
# 1868                31.0              Pacífico
# 1949                32.0               Adelfas
# 2026                33.0              Estrella
# 2104                34.0                 Ibiza
# 2180                35.0         Los Jerónimos
# 2256                36.0            Niño Jesús
# 2652                41.0             Recoletos

# %% [markdown]
# ### Observations
# Inspection of the neighbourhood names shows that accents are retained; however, unlike the housing prices dataset, the names do not contain numerical prefixes or punctuation (e.g '011. Palacio' vs 'Palacio) . Therefore, it is was decided to standardise the neighbourhood names in the housing prices dataset to match the format used in this dataset, creating a consistent key for merging.

# %% [markdown]
# ### Exploring Neighbourhood-Level Indicators and Categories

# %%
# Display information for one neighbourhood in 2025

palacio = indicators_clean_n.loc[
    (indicators_clean_n['dataset_version'] == 2025) &
    (indicators_clean_n['neighbourhood_name']== 'Palacio')]
palacio
# Out:
#         row_no  dataset_version              city  district_code  \
# 96528    96529             2025  Ciudad de Madrid            1.0
# 96529    96530             2025  Ciudad de Madrid            1.0
# 96530    96531             2025  Ciudad de Madrid            1.0
# 96531    96532             2025  Ciudad de Madrid            1.0
# 96532    96533             2025  Ciudad de Madrid            1.0
# ...        ...              ...               ...            ...
# 116034  116035             2025  Ciudad de Madrid            1.0
# 116190  116191             2025  Ciudad de Madrid            1.0
# 116191  116192             2025  Ciudad de Madrid            1.0
# 116192  116193             2025  Ciudad de Madrid            1.0
# 116193  116194             2025  Ciudad de Madrid            1.0
#
#        district_name  neighbourhood_code neighbourhood_name  year        date  \
# 96528         Centro                11.0            Palacio  2025  01/01/2025
# 96529         Centro                11.0            Palacio  2025  01/01/2025
# 96530         Centro                11.0            Palacio  2025  01/01/2025
# 96531         Centro                11.0            Palacio  2025  01/01/2025
# 96532         Centro                11.0            Palacio  2025  01/01/2025
# ...              ...                 ...                ...   ...         ...
# 116034        Centro                11.0            Palacio  2023  01/01/2023
# 116190        Centro                11.0            Palacio  2025  01/01/2025
# 116191        Centro                11.0            Palacio  2025  01/01/2025
# 116192        Centro                11.0            Palacio  2025  01/01/2025
# 116193        Centro                11.0            Palacio  2025  01/01/2025
#
#                                               data_source  \
# 96528                  Estadística Ayuntamiento de Madrid
# 96529                  Estadística Ayuntamiento de Madrid
# 96530                  Estadística Ayuntamiento de Madrid
# 96531                  Estadística Ayuntamiento de Madrid
# 96532                  Estadística Ayuntamiento de Madrid
# ...                                                   ...
# 116034                 Estadística Ayuntamiento de Madrid
# 116190  Portal de datos abiertos del Ayuntamiento de M...
# 116191  Portal de datos abiertos del Ayuntamiento de M...
# 116192  Portal de datos abiertos del Ayuntamiento de M...
# 116193  Portal de datos abiertos del Ayuntamiento de M...
#
#                                         main_category  \
# 96528   Características Generales del Distrito-Barrio
# 96529   Características Generales del Distrito-Barrio
# 96530                          Población del distrito
# 96531                          Población del distrito
# 96532                          Población del distrito
# ...                                               ...
# 116034                         Indicadores Económicos
# 116190                             Empresa y comercio
# 116191                             Empresa y comercio
# 116192                             Empresa y comercio
# 116193                             Empresa y comercio
#
#                          subcategory       indicator_level1 indicator_level2  \
# 96528                            NaN             Superficie              NaN
# 96529                            NaN  Densidad de población              NaN
# 96530        Estructura de población   Número de Habitantes              NaN
# 96531        Estructura de población   Número de Habitantes          Hombres
# 96532        Estructura de población   Número de Habitantes          Mujeres
# ...                              ...                    ...              ...
# 116034        Indicadores económicos                 Renta             Neta
# 116190                 Total locales                Locales            Total
# 116191              Locales abiertos                Locales         Abiertos
# 116192              Locales cerrados                Locales         Cerrados
# 116193  Locales en uso como vivienda                Locales     Uso vivienda
#
#        indicator_level3            unit  \
# 96528               NaN              Ha
# 96529               NaN  Habitantes/Ha.
# 96530               NaN      Habitantes
# 96531               NaN      Habitantes
# 96532               NaN      Habitantes
# ...                 ...             ...
# 116034       Per cápita           Renta
# 116190              NaN          Número
# 116191              NaN          Número
# 116192              NaN          Número
# 116193              NaN          Número
#
#                                            indicator_name indicator_value
# 96528                                    Superficie (ha.)          146,99
# 96529                       Población densidad (hab./ha.)     163,2832165
# 96530                                   Número habitantes           24001
# 96531                                   Población hombres           11693
# 96532                                   Población mujeres           12308
# ...                                                   ...             ...
# 116034                 Renta media disponible por persona           23770
# 116190            Número de locales dados de alta totales            3062
# 116191           Número de locales dados de alta abiertos            2617
# 116192           Número de locales dados de alta cerrados             445
# 116193  Número de locales dados de alta en uso como vi...              66
#
# [119 rows x 18 columns]

# %%
# Display the diffrerent main categories of the indicators
palacio["main_category"].nunique()
# Out:
# 11

# %%
# Display the counts across the main categories of the indicators

palacio["main_category"].value_counts()
# Out:
# main_category
# Población del distrito                           32
# Educación                                        22
# Servicios y equipamientos Municipales            16
# Indicadores Población desempleo                  12
# Resultados Elecciones Locales                    10
# Vivienda                                          6
# Índice de vulnerabilidad                          5
# Empresa y comercio                                5
# Participación ciudadana                           5
# Indicadores Económicos                            4
# Características Generales del Distrito-Barrio     2
# Name: count, dtype: int64

# %% [markdown]
# English translation of main categories (Source: Google translate)
#
# main_category
# District population                              32
# Education                                        22
# Municipal services and facilities                16
# Population and unemployment indicators           12
# Local election results                           10
# Housing                                           6
# Vulnerability index                               5
# Business and commerce                             5
# Citizen participation                             5
# Economic indicators                               4
# General characteristics of the district/neighborhood 2
# Name: count, dtype: int64

# %%
# Display the diffrerent subcategories of the indicators
palacio["subcategory"].nunique()
# Out:
# 18

# %%
# Display the different subcategories of the indicators

palacio["subcategory"].value_counts()
# Out:
# subcategory
# Estructura de población                 24
# Población en etapas educativas          15
# Población desempleo                     12
# Servicios Sociales Municipales           8
# Nivel de estudios de la población        7
# Estructura de los hogares                6
# Territorial                              5
# Entidades de participación ciudadana     5
# Deportes                                 4
# Indicadores económicos                   4
# Dinámica demográfica                     2
# Cultura                                  2
# Educación                                2
# Recursos municipales                     1
# Total locales                            1
# Locales abiertos                         1
# Locales cerrados                         1
# Locales en uso como vivienda             1
# Name: count, dtype: int64

# %% [markdown]
# English translation of subcategories (Source: Google translate)
#
# subcategory
# Population structure                   24
# Population by educational stage        15
# Unemployment                           12
# Municipal social services               8
# Population's educational attainment     7
# Household structure                     6
# Territorial                             5
# Citizen participation bodies            5
# Sports                                  4
# Economic indicators                     4
# Demographic dynamics                    2
# Culture                                 2
# Education                               2
# Municipal resources                     1
# Total premises                          1
# Open premises                           1
# Closed premises                         1
# Premises used as housing                1
# Name: count, dtype: int64

# %% [markdown]
# ### Observations
#
# Exploration of the 2025 data for the Palacio neighbourhood shows 119 rows of information, covering 11 main categories and 18 subcategories. While these categories can provide useful context for organising the data, observations are heavily concentrated within a small number of categories. Therefore, feature selection will focus primarily on the individual indicator_name values, which provide more specific information about the socioeconomic characteristics available for modelling.

# %%
# Check the number of indicator records per neighbourhood in 2025
neighbourhood_catalog = (indicators_clean_n[indicators_clean_n["dataset_version"] == 2025]
    .groupby("neighbourhood_name")
    .size()
    .reset_index(name="row_count")
)
neighbourhood_catalog
# Out:
#     neighbourhood_name  row_count
# 0             Abrantes        111
# 1              Acacias        115
# 2              Adelfas        115
# 3           Aeropuerto        107
# 4     Alameda de Osuna        116
# ..                 ...        ...
# 126          Vinateros        112
# 127       Vista Alegre        119
# 128              Zofío        114
# 129            Águilas        119
# 130            Ángeles        115
#
# [131 rows x 2 columns]

# %%
# Saving the number of indicator records per neighbourhood in 2025 in an excel
neighbourhood_catalog.to_excel(
    "../outputs/neighbourhood_catalog.xlsx",
    index=False
)

# %% [markdown]
# ### Observations
#
# The 131 neighbourhoods contain between 106 and 122 indicator records for 2025. While the number of records varies, overall indicator coverage appears broadly similar across neighbourhoods.

# %%
# Retain only columns with information on types of indicies using palacio 
n_indicator_catalog= palacio[
    [
        "main_category",
        "subcategory",
        "indicator_name",
        "unit"
    ]]

# %%
# Remove duplicates
n_indicator_catalog = n_indicator_catalog.drop_duplicates()

# %%
# Sort alphabetically
n_indicator_catalog = n_indicator_catalog.sort_values(
    ["main_category", "subcategory", "indicator_name"]
)

# %%
# Save to Excel
n_indicator_catalog.to_excel(
    "../outputs/n_indicator_catalog.xlsx",
    index=False
)

# %% [markdown]
# ### Observations
#
# To simplify exploration of the large dataset, indicator information for Palacio was selected as a representative neighbourhood. The main_category, subcategory, indicator_name and unit columns were exported to a catalogue for further review and feature selection.

# %% [markdown]
# ### Selecting features for the ML model
# The indicator catalogue was reviewed and 15 socioeconomic features were selected for the machine learning model. The catalogue was annotated during the review process and saved in the outputs folder as n_indicator_catalog_feature_selection.xlsx
#
# #### Selected Features:
#
# Some features required multiple indicators to be combined to calculate a percentage and are marked with an asterisk (*).
#
# No.	Selected Feature Variable
# - 1	Population density (inhabitants per hectare)
# - 2	Percentage of population aged 25+ with higher education (university degree, postgraduate or doctorate) or diploma/technical degree *
# - 3	Percentage of registered housing over total registered premises *
# - 4	Average disposable income per person
# - 5	Average annual net household income (Urban Audit)
# - 6	Registered unemployment rate (February)
# - 7	Population growth rate (%)
# - 8	Average household size
# - 9	Average age
# - 10 Ageing index (% aged 65+)
# - 11 Social welfare and equality vulnerability index
# - 12 Economic and employment vulnerability index
# - 13 Education and culture vulnerability index
# - 14 Urban environment and mobility vulnerability index
# - 15 Health vulnerability index
#
# These selected features, and the component indicators required to create them, will be extracted and prepared during the data preparation stage

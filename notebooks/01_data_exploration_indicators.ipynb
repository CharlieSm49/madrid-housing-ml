# %% [markdown]
# # Predicting Average House Prices in Madrid Neighbourhoods Using Socioeconomic Indicators

# %% [markdown]
# ## Overall Project Aim:
# To develop and evaluate a machine learning model that uses 2025 socioeconomic indicators to predict average housing prices across Madrid neighbourhoods.

# %% [markdown]
# ## 1. Data Inspection

# %% [markdown]
# ### Introduction
# Two datasets are used in this project:
#
# - Panel of Socioeconomic Indicators of Districts and Neighbourhoods of Madrid (indicators.csv)
# - Madrid Average Declared Housing Price (€ per m²) by District and Neighbourhood (prices.csv)
#
# This notebook focuses on exploring the raw Madrid socioeconomic indicator dataset. The dataset contains multiple socioeconomic indicators across several years and includes data at both district and neighbourhood level.

# %% [markdown]
# ### Import Libraries

# %%
# Import the Pandas library for data manipulation and analysis
import pandas as pd

# %% [markdown]
# ### Load Dataset

# %%
# Loading Dataset 1: Panel of Sociodemographic Indicators of Districts and Neighborhoods of Madrid
indicators = pd.read_csv("../data/indicators.csv",sep=";")

# %% [markdown]
# ### Initial Inspection

# %%
# Display the first ten rows
indicators.head(10)
# Out:
#    Orden  Periodo panel            ciudad  cod_distrito distrito  cod_barrio  \
# 0      1           2020  Ciudad de Madrid           1.0   Centro         NaN
# 1      2           2020  Ciudad de Madrid           1.0   Centro         NaN
# 2      3           2020  Ciudad de Madrid           1.0   Centro         NaN
# 3      4           2020  Ciudad de Madrid           1.0   Centro         NaN
# 4      5           2020  Ciudad de Madrid           1.0   Centro         NaN
# 5      6           2020  Ciudad de Madrid           1.0   Centro         NaN
# 6      7           2020  Ciudad de Madrid           1.0   Centro         NaN
# 7      8           2020  Ciudad de Madrid           1.0   Centro         NaN
# 8      9           2020  Ciudad de Madrid           1.0   Centro         NaN
# 9     10           2020  Ciudad de Madrid           1.0   Centro         NaN
#
#   barrio   año fecha_indicador                    fuente_indicador  \
# 0    NaN  2019      01/01/2019  Estadística Ayuntamiento de Madrid
# 1    NaN  2019      01/01/2019  Estadística Ayuntamiento de Madrid
# 2    NaN  2019      01/01/2019  Estadística Ayuntamiento de Madrid
# 3    NaN  2019      01/01/2019  Estadística Ayuntamiento de Madrid
# 4    NaN  2019      01/01/2019  Estadística Ayuntamiento de Madrid
# 5    NaN  2019      01/01/2019  Estadística Ayuntamiento de Madrid
# 6    NaN  2019      01/01/2019  Estadística Ayuntamiento de Madrid
# 7    NaN  2019      01/01/2019  Estadística Ayuntamiento de Madrid
# 8    NaN  2019      01/01/2019  Estadística Ayuntamiento de Madrid
# 9    NaN  2019      01/01/2019  Estadística Ayuntamiento de Madrid
#
#                                      categoría_1              categoría_2  \
# 0  Características Generales del Distrito-Barrio                      NaN
# 1  Características Generales del Distrito-Barrio                      NaN
# 2                         Población del distrito  Estructura de población
# 3                         Población del distrito  Estructura de población
# 4                         Población del distrito  Estructura de población
# 5                         Población del distrito  Estructura de población
# 6                         Población del distrito  Estructura de población
# 7                         Población del distrito  Estructura de población
# 8                         Población del distrito  Estructura de población
# 9                         Población del distrito  Estructura de población
#
#         indicador_nivel1 indicador_nivel2 indicador_nivel3 unidad_indicador  \
# 0             Superficie              NaN              NaN               Ha
# 1  Densidad de población              NaN              NaN   Habitantes/Ha.
# 2   Número de Habitantes              NaN              NaN       Habitantes
# 3   Número de Habitantes          Hombres              NaN       Habitantes
# 4   Número de Habitantes          Mujeres              NaN       Habitantes
# 5             Edad Media              NaN              NaN             Edad
# 6   Número de Habitantes             0-14              NaN         Personas
# 7   Número de Habitantes            15-29              NaN         Personas
# 8   Número de Habitantes            30-44              NaN         Personas
# 9   Número de Habitantes            45-64              NaN         Personas
#
#               indicador_completo valor_indicador
# 0               Superficie (ha.)             523
# 1  Población densidad (hab./ha.)             258
# 2              Número habitantes          134881
# 3              Población hombres           67829
# 4              Población mujeres           67052
# 5     Edad media de la población           44,03
# 6       Población de 0 a 14 años           10554
# 7      Población de 15 a 29 años           21800
# 8      Población de 30 a 44 años           42857
# 9      Población de 45 a 64 años           38025

# %%
# Display the last five rows
indicators.tail()
# Out:
#          Orden  Periodo panel            ciudad  cod_distrito  \
# 116903  116904           2025  Ciudad de Madrid          18.0
# 116904  116905           2025  Ciudad de Madrid          19.0
# 116905  116906           2025  Ciudad de Madrid          20.0
# 116906  116907           2025  Ciudad de Madrid          21.0
# 116907  116908           2025  Ciudad de Madrid           NaN
#
#                    distrito  cod_barrio barrio   año fecha_indicador  \
# 116903    Villa de Vallecas         NaN    NaN  2024      01/01/2024
# 116904            Vicálvaro         NaN    NaN  2024      01/01/2024
# 116905  San Blas-Canillejas         NaN    NaN  2024      01/01/2024
# 116906              Barajas         NaN    NaN  2024      01/01/2024
# 116907                  NaN         NaN    NaN  2024      01/01/2024
#
#                           fuente_indicador categoría_1  \
# 116903  Estadística Ayuntamiento de Madrid       Salud
# 116904  Estadística Ayuntamiento de Madrid       Salud
# 116905  Estadística Ayuntamiento de Madrid       Salud
# 116906  Estadística Ayuntamiento de Madrid       Salud
# 116907  Estadística Ayuntamiento de Madrid       Salud
#
#                     categoría_2   indicador_nivel1           indicador_nivel2  \
# 116903  Discapacidad reconocida  Número de mujeres  Feminización Discapacidad
# 116904  Discapacidad reconocida  Número de mujeres  Feminización Discapacidad
# 116905  Discapacidad reconocida  Número de mujeres  Feminización Discapacidad
# 116906  Discapacidad reconocida  Número de mujeres  Feminización Discapacidad
# 116907  Discapacidad reconocida  Número de mujeres  Feminización Discapacidad
#
#        indicador_nivel3 unidad_indicador  \
# 116903          Mujeres       Porcentaje
# 116904          Mujeres       Porcentaje
# 116905          Mujeres       Porcentaje
# 116906          Mujeres       Porcentaje
# 116907          Mujeres       Porcentaje
#
#                                        indicador_completo valor_indicador
# 116903  Mujeres por cada 100 hombres (feminización de ...           106,3
# 116904  Mujeres por cada 100 hombres (feminización de ...          101,31
# 116905  Mujeres por cada 100 hombres (feminización de ...           97,54
# 116906  Mujeres por cada 100 hombres (feminización de ...          100,64
# 116907  Mujeres por cada 100 hombres (feminización de ...          110,04

# %%
# Display ten random rows
indicators.sample(10)
# Out:
#        Orden  Periodo panel            ciudad  cod_distrito  \
# 46705  46706           2022  Ciudad de Madrid          11.0
# 73782  73783           2023  Ciudad de Madrid          21.0
# 53004  53005           2022  Ciudad de Madrid          20.0
# 39055  39056           2022  Ciudad de Madrid           2.0
# 51426  51427           2022  Ciudad de Madrid          17.0
# 31510  31511           2021  Ciudad de Madrid          16.0
# 93958  93959           2024  Ciudad de Madrid           8.0
# 99263  99264           2025  Ciudad de Madrid           4.0
# 62762  62763           2023  Ciudad de Madrid           7.0
# 1239    1240           2020  Ciudad de Madrid           2.0
#
#                   distrito  cod_barrio            barrio   año  \
# 46705          Carabanchel       112.0            Opañel  2021
# 73782              Barajas         NaN               NaN  2023
# 53004  San Blas-Canillejas       206.0             Rejas  2021
# 39055           Arganzuela         NaN               NaN  2020
# 51426           Villaverde       175.0           Ángeles  2021
# 31510            Hortaleza       165.0  Apóstol Santiago  2020
# 93958  Fuencarral-El Pardo         NaN               NaN  2023
# 99263            Salamanca         NaN               NaN  2024
# 62762             Chamberí        76.0      Vallehermoso  2022
# 1239            Arganzuela        24.0           Legazpi  2019
#
#       fecha_indicador                                   fuente_indicador  \
# 46705      01/01/2021                 Estadística Ayuntamiento de Madrid
# 73782      01/01/2023                 Estadística Ayuntamiento de Madrid
# 53004      01/01/2021                 Estadística Ayuntamiento de Madrid
# 39055      01/01/2020                 Estadística Ayuntamiento de Madrid
# 51426      01/01/2021                 Estadística Ayuntamiento de Madrid
# 31510      01/01/2020                 Estadística Ayuntamiento de Madrid
# 93958      28/05/2023                 Estadística Ayuntamiento de Madrid
# 99263      01/01/2024  Portal de datos abiertos del Ayuntamiento de M...
# 62762      01/01/2022                 Estadística Ayuntamiento de Madrid
# 1239       01/01/2019                 Estadística Ayuntamiento de Madrid
#
#                                  categoría_1                categoría_2  \
# 46705                 Población del distrito    Estructura de población
# 73782                 Población del distrito    Estructura de población
# 53004                 Población del distrito  Estructura de los hogares
# 39055                 Población del distrito       Dinámica demográfica
# 51426                 Población del distrito    Estructura de población
# 31510                               Vivienda                        NaN
# 93958          Resultados Elecciones Locales                        NaN
# 99263  Servicios y equipamientos Municipales                  Educación
# 62762                 Población del distrito    Estructura de población
# 1239                  Población del distrito    Estructura de población
#
#               indicador_nivel1                       indicador_nivel2  \
# 46705     Número de Habitantes                                Mujeres
# 73782     Número de Habitantes                                  65-79
# 53004        Número de Hogares  hombre solo mayor de 65 años
# 39055        Esperanza de vida                                Hombres
# 51426     Número de Habitantes                                Hombres
# 31510                Inmuebles                        Uso residencial
# 93958          Número de votos                 Más Madrid-Verdes Equo
# 99263  Número de equipamientos                    Escuelas infantiles
# 62762     Número de Habitantes                                Hombres
# 1239      Número de Habitantes                               65 y más
#
#               indicador_nivel3 unidad_indicador  \
# 46705  Nacionalidad extranjera         Personas
# 73782                      NaN         Personas
# 53004                      NaN          Hogares
# 39055                      NaN             Edad
# 51426  Nacionalidad extranjera         Personas
# 31510         Superficie media               m2
# 93958                Municipio            Votos
# 99263                 Privadas    Equipamientos
# 62762    Nacionalidad española         Personas
# 1239                       NaN         Personas
#
#                                       indicador_completo valor_indicador
# 46705       Personas con nacionalidad extranjera mujeres            4141
# 73782                          Población de 65 a 79 años            6699
# 53004        Hogares con un hombre solo mayor de 65 años             137
# 39055                 Esperanza de vida al nacer hombres              79
# 51426       Personas con nacionalidad extranjera hombres            2885
# 31510  Superficie media construida (m2) inmuebles de ...             108
# 93958  Elecciones municipales, votos a Más Madrid-Ver...           19095
# 99263                       Escuelas infantiles privadas              11
# 62762         Personas con nacionalidad española hombres            8053
# 1239                          Población de 65 años y más            1702

# %%
# Check the number of rows and columns
indicators.shape
# Out:
# (116908, 18)

# %%
# Display all column names
indicators.columns
# Out:
# Index(['Orden', 'Periodo panel', 'ciudad', 'cod_distrito', 'distrito',
#        'cod_barrio', 'barrio', 'año', 'fecha_indicador', 'fuente_indicador',
#        'categoría_1', 'categoría_2', 'indicador_nivel1', 'indicador_nivel2',
#        'indicador_nivel3', 'unidad_indicador', 'indicador_completo',
#        'valor_indicador'],
#       dtype='str')

# %% [markdown]
# #### Column Translation Key
#
# The original Spanish column names have been translated into English. (Source: Google translate)
#
# Output of column names (English):
#
# Index(['Order', 'Panel period', 'City', 'District code', 'District',
#        'Neighborhood code', 'Neighborhood', 'Year', 'Indicator date', 'Indicator source',
#        'Category 1', 'Category 2', 'Indicator level 1', 'Indicator level 2',
#        'Indicator level 3', 'Indicator unit', 'Full indicator name',
#        'Indicator value'],
#       dtype='object')

# %% [markdown]
# ### Observations
#
# The dataset contains multi-year data at both district and neighbourhood level. Each row represents an individual indicator and its value, organised by indicator type and subcategory. For example, separate rows may represent the number of male and female inhabitants within the same district and year.
#
# As the model will focus on 2025 data at neighbourhood level, the data requires filtering by year and geographical level, followed by restructuring to support feature selection and modelling.

# %% [markdown]
# ### Data Types

# %%
# Display the data type of each column
indicators.dtypes
# Out:
# Orden                   int64
# Periodo panel           int64
# ciudad                    str
# cod_distrito          float64
# distrito                  str
# cod_barrio            float64
# barrio                    str
# año                     int64
# fecha_indicador           str
# fuente_indicador          str
# categoría_1               str
# categoría_2               str
# indicador_nivel1          str
# indicador_nivel2          str
# indicador_nivel3          str
# unidad_indicador          str
# indicador_completo        str
# valor_indicador           str
# dtype: object

# %%
# Display dataset information
indicators.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 116908 entries, 0 to 116907
# Data columns (total 18 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Orden               116908 non-null  int64
#  1   Periodo panel       116908 non-null  int64
#  2   ciudad              116908 non-null  str
#  3   cod_distrito        115105 non-null  float64
#  4   distrito            115105 non-null  str
#  5   cod_barrio          84570 non-null   float64
#  6   barrio              84570 non-null   str
#  7   año                 116908 non-null  int64
#  8   fecha_indicador     116908 non-null  str
#  9   fuente_indicador    116908 non-null  str
#  10  categoría_1         116908 non-null  str
#  11  categoría_2         100705 non-null  str
#  12  indicador_nivel1    116908 non-null  str
#  13  indicador_nivel2    103504 non-null  str
#  14  indicador_nivel3    48898 non-null   str
#  15  unidad_indicador    116908 non-null  str
#  16  indicador_completo  116908 non-null  str
#  17  valor_indicador     116908 non-null  str
# dtypes: float64(2), int64(3), str(13)
# memory usage: 42.2 MB

# %% [markdown]
# ### Observations
# valor_indicador (indicator value) is a key column containing the numerical value for each socioeconomic indicator. It is currently stored as a string and will need to be converted to a numerical data type (e.g float) before modelling.

# %%
# Summary statistics of the numerical columns
indicators.describe()
# Out:
#                Orden  Periodo panel   cod_distrito    cod_barrio  \
# count  116908.000000  116908.000000  115105.000000  84570.000000
# mean    58454.500000    2022.539561      10.777282    110.687194
# std     33748.576972       1.713728       5.911289     58.583824
# min         1.000000    2020.000000       1.000000     11.000000
# 25%     29227.750000    2021.000000       6.000000     62.000000
# 50%     58454.500000    2023.000000      11.000000    111.000000
# 75%     87681.250000    2024.000000      15.000000    158.000000
# max    116908.000000    2025.000000      21.000000    215.000000
#
#                  año
# count  116908.000000
# mean     2021.616776
# std         1.946883
# min      2008.000000
# 25%      2020.000000
# 50%      2022.000000
# 75%      2023.000000
# max      2025.000000

# %%
# Summary statistics for all columns
indicators.describe(include="all")
# Out:
#                 Orden  Periodo panel            ciudad   cod_distrito  \
# count   116908.000000  116908.000000            116908  115105.000000
# unique            NaN            NaN                 1            NaN
# top               NaN            NaN  Ciudad de Madrid            NaN
# freq              NaN            NaN            116908            NaN
# mean     58454.500000    2022.539561               NaN      10.777282
# std      33748.576972       1.713728               NaN       5.911289
# min          1.000000    2020.000000               NaN       1.000000
# 25%      29227.750000    2021.000000               NaN       6.000000
# 50%      58454.500000    2023.000000               NaN      11.000000
# 75%      87681.250000    2024.000000               NaN      15.000000
# max     116908.000000    2025.000000               NaN      21.000000
#
#              distrito    cod_barrio  \
# count          115105  84570.000000
# unique             21           NaN
# top     Ciudad Lineal           NaN
# freq             7183           NaN
# mean              NaN    110.687194
# std               NaN     58.583824
# min               NaN     11.000000
# 25%               NaN     62.000000
# 50%               NaN    111.000000
# 75%               NaN    158.000000
# max               NaN    215.000000
#
#                                                  barrio            año  \
# count                                             84570  116908.000000
# unique                                              131            NaN
# top     Villaverde Alto - Casco Histórico de Villaverde            NaN
# freq                                                707            NaN
# mean                                                NaN    2021.616776
# std                                                 NaN       1.946883
# min                                                 NaN    2008.000000
# 25%                                                 NaN    2020.000000
# 50%                                                 NaN    2022.000000
# 75%                                                 NaN    2023.000000
# max                                                 NaN    2025.000000
#
#        fecha_indicador                    fuente_indicador  \
# count           116908                              116908
# unique              31                                  12
# top         01/01/2023  Estadística Ayuntamiento de Madrid
# freq             17246                               89172
# mean               NaN                                 NaN
# std                NaN                                 NaN
# min                NaN                                 NaN
# 25%                NaN                                 NaN
# 50%                NaN                                 NaN
# 75%                NaN                                 NaN
# max                NaN                                 NaN
#
#                    categoría_1              categoría_2    indicador_nivel1  \
# count                   116908                   100705              116908
# unique                      19                       53                  46
# top     Población del distrito  Estructura de población  Número de personas
# freq                     31665                    23170               29881
# mean                       NaN                      NaN                 NaN
# std                        NaN                      NaN                 NaN
# min                        NaN                      NaN                 NaN
# 25%                        NaN                      NaN                 NaN
# 50%                        NaN                      NaN                 NaN
# 75%                        NaN                      NaN                 NaN
# max                        NaN                      NaN                 NaN
#
#        indicador_nivel2 indicador_nivel3 unidad_indicador indicador_completo  \
# count            103504            48898           116908             116908
# unique              226               65               41                381
# top             Mujeres        Municipio         Personas   Superficie (ha.)
# freq               9010             8711            44180                918
# mean                NaN              NaN              NaN                NaN
# std                 NaN              NaN              NaN                NaN
# min                 NaN              NaN              NaN                NaN
# 25%                 NaN              NaN              NaN                NaN
# 50%                 NaN              NaN              NaN                NaN
# 75%                 NaN              NaN              NaN                NaN
# max                 NaN              NaN              NaN                NaN
#
#        valor_indicador
# count           116908
# unique           28852
# top                  1
# freq              5245
# mean               NaN
# std                NaN
# min                NaN
# 25%                NaN
# 50%                NaN
# 75%                NaN
# max                NaN

# %% [markdown]
# ### Missing Values and Duplicates

# %%
# Count missing values
indicators.isnull().sum()
# Out:
# Orden                     0
# Periodo panel             0
# ciudad                    0
# cod_distrito           1803
# distrito               1803
# cod_barrio            32338
# barrio                32338
# año                       0
# fecha_indicador           0
# fuente_indicador          0
# categoría_1               0
# categoría_2           16203
# indicador_nivel1          0
# indicador_nivel2      13404
# indicador_nivel3      68010
# unidad_indicador          0
# indicador_completo        0
# valor_indicador           0
# dtype: int64

# %%
# Count duplicate rows
indicators.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Count number of unique values in each column
indicators.nunique()
# Out:
# Orden                 116908
# Periodo panel              6
# ciudad                     1
# cod_distrito              21
# distrito                  21
# cod_barrio               131
# barrio                   131
# año                       18
# fecha_indicador           31
# fuente_indicador          12
# categoría_1               19
# categoría_2               53
# indicador_nivel1          46
# indicador_nivel2         226
# indicador_nivel3          65
# unidad_indicador          41
# indicador_completo       381
# valor_indicador        28852
# dtype: int64

# %% [markdown]
# ### Observations
#
# Initial summary statistics are of limited value at this stage, as the data has not yet been cleaned. Missing values indicate that not every indicator has a corresponding district, neighbourhood, subcategory or specific indicator value. No duplicate rows were identified. The dataset contains 21 districts and 131 neighbourhoods, consistent with the official counts for Madrid. These initial observations will inform the subsequent data cleaning and feature selection processes.
